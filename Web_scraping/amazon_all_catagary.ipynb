# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

##Amazon Launchpad

url="https://www.amazon.in/gp/bestsellers/boost/ref=zg_bs_nav_0"
page=requests.get(url)
soup=BeautifulSoup(page.content,'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start --><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
#
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
#
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
all_data=soup.find_all(class_="p13n-sc-uncoverable-faceout")
len(all_data)
# Out:
# 50

# %%
first=all_data[0]
first
# Out:
# <div class="p13n-sc-uncoverable-faceout" id="B0B6W5KCRM"><a class="a-link-normal" href="/Avimee-Keshpallav-Reduces-dandruff-Promotes/dp/B0B6W5KCRM/ref=zg_bs_boost_sccl_1/000-0000000-0000000?psc=1" role="link" tabindex="-1"><div class="a-section a-spacing-mini _cDEzb_noop_3Xbw5"><img alt="Avimee Herbal Keshpallav Hair Oil for Men and Women | Reduces Hair fall &amp; dandruff | Promotes Hair Growth | 100 ML" class="a-dynamic-image p13n-sc-dynamic-image p13n-product-image" data-a-dynamic-image='{"https://images-eu.ssl-images-amazon.com/images/I/71wLE4HgSLL._AC_UL300_SR300,200_.jpg":[300,200],"https://images-eu.ssl-images-amazon.com/images/I/71wLE4HgSLL._AC_UL600_SR600,400_.jpg":[600,400],"https://images-eu.ssl-images-amazon.com/images/I/71wLE4HgSLL._AC_UL900_SR900,600_.jpg":[900,600]}' height="200px" src="https://images-eu.ssl-images-amazon.com/images/I/71wLE4HgSLL._AC_UL300_SR300,200_.jpg" style="max-width:300px;max-height:200px"/></div></a><a class="a-link-normal" href="/Avimee-Keshpal
# ...

# %%
info=[t.get_text().replace('|','')for t in first.find(class_="_cDEzb_p13n-sc-css-line-clamp-3_g3dy1")]
info
# Out:
# ['Avimee Herbal Keshpallav Hair Oil for Men and Women  Reduces Hair fall & dandruff  Promotes Hair Growth  100 ML']

# %%
#info=[first.find(class_="_cDEzb_p13n-sc-css-line-clamp-3_g3dy1").get_text().replace('|','').split()[9:]]
#info

# %%
rating= first.find_all(class_="a-link-normal")[2].find_all('span')[0].get_text()
rating
# Out:
# '4.1 out of 5 stars'

# %%
review=[t.get_text() for t in first.find(class_="a-size-small")]
review
# Out:
# ['623']

# %%
price=first.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text()
price
# Out:
# '₹495.00'

# %%
info ,rating ,review ,price=[],[],[],[]

for first in all_data:
    
    info.append([t.get_text().replace('|','')for t in first.find(class_="_cDEzb_p13n-sc-css-line-clamp-3_g3dy1")])
    rating.append(first.find_all(class_="a-link-normal")[2].find_all('span')[0].get_text())

    review.append([t.get_text()for t in first.find_all(class_="a-size-small")])
    price.append(first.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())


    
len(info),len(rating),len(review),len(price)
# Out:
# (50, 50, 50, 50)

# %%
d={'information':info,'Rating':rating,'Review':review,'Price':price}

# %%
df=pd.DataFrame(d)
df
# Out:
#                                           information              Rating  \
# 0   [Avimee Herbal Keshpallav Hair Oil for Men and...  4.1 out of 5 stars
# 1   [Mamaearth Ubtan Natural Face Wash for All Ski...  4.1 out of 5 stars
# 2   [Be Bodywise Biotin Hair Gummies for Stronger,...  4.0 out of 5 stars
# 3   [Bodywise 1% Salicylic Acid Body Wash, 250ml H...  4.2 out of 5 stars
# 4   [INDIGENOUS HONEY Raw Organic Honey NMR Tested...  4.4 out of 5 stars
# 5   [Man Matters Biotin Hair Gummies  60 Days Pack...  3.8 out of 5 stars
# 6   [Mother Sparsh 99% Pure Water (Unscented) Baby...  4.5 out of 5 stars
# 7   [Avimee Herbal Keshpallav Hair Oil (100 ml) & ...  4.1 out of 5 stars
# 8   [Avimee Herbal Hair tone PV 1 Scalp Spray for ...  4.2 out of 5 stars
# 9   [ASGARD Nonwoven Fabric Disposable Multilayer ...  4.3 out of 5 stars
# 10  [Chemist At Play Under-Arm Roll On, Prevents O...  4.2 out of 5 stars
# 11  [Desidiya ® 20 Photo Clip LED String Lights fo...  4.0 out of 5 stars
# ...

# %%
info ,rating ,review ,price=[],[],[],[]

for i in range(1,3):
    
    url=f"https://www.amazon.in/gp/bestsellers/boost/ref=zg_bs_nav_{i}"
    page=requests.get(url)
    soup=BeautifulSoup(page.content,'html5lib')
    all_data=soup.find_all(class_="p13n-sc-uncoverable-faceout")
       
    for first in all_data:
    
        info.append([t.get_text().replace('|','')for t in first.find(class_="_cDEzb_p13n-sc-css-line-clamp-3_g3dy1")])
        rating.append(first.find_all(class_="a-link-normal")[2].find_all('span')[0].get_text())

        review.append([t.get_text()for t in first.find_all(class_="a-size-small")])
        price.append(first.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())


    
len(info),len(rating),len(review),len(price)
# Out:
# (100, 100, 100, 100)

# %%
d={'information':info,'Rating':rating,'Review':review,'Price':price}

# %%
df=pd.DataFrame(d)
df.to_csv('Bestsellers in Amazon Launchpad.csv')

# %% [markdown]
# ## Bestsellers in Amazon Renewed

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url="https://www.amazon.in/gp/bestsellers/amazon-renewed/ref=zg_bs_nav_0"
page=requests.get(url)
soup=BeautifulSoup(page.content,'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start --><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
#
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
#
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
all_data=soup.find_all(class_="a-column a-span12 a-text-center _cDEzb_grid-column_2hIsc")
len(all_data)
# Out:
# 50

# %%
renew=all_data[0]

# %%
info=renew.find_all(class_="a-link-normal")[1].get_text()
info
# Out:
# '(Renewed) boAt Rockerz 550 Bluetooth Over-Ear Wireless Headphone with Ergonomic Aesthetics Plush Padded Earcups Immersive Audio Bluetooth v5.0 & Upto 20H Playback (Black)'

# %%
rating=renew.find_all(class_="a-link-normal")[-2].find_all('span')[0].get_text()
rating
# Out:
# '3.8 out of 5 stars'

# %%
review=renew.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text()
review
# Out:
# '989'

# %%
price=renew.find_all(class_="a-link-normal")[-1].find_all('span')[1].get_text()
price
# Out:
# '₹1,189.00'

# %%
info,rating,review,price=[],[],[],[]

for t in all_data:
    res=t.find_all(class_="a-link-normal")
    if len(res)==4:
        info.append([t.find_all(class_="a-link-normal")[1].get_text()])
        rating.append([t.find_all(class_="a-link-normal")[-2].find_all('span')[0].get_text()])
        review.append([t.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text()])
        price.append([t.find_all(class_="a-link-normal")[-1].find_all('span')[1].get_text()])
    else:
        info.append([t.find_all(class_="a-link-normal")[1].get_text()])
        rating.append([t.find_all(class_="a-link-normal")[-1].find_all('span')[0].get_text()])
        review.append([t.find_all(class_="a-link-normal")[-1].find_all('span')[1].get_text()])
        price.append('Noun')


        
    
    
    
len(info),len(rating),len(review),len(price)
# Out:
# (50, 50, 50, 50)

# %%
d={'information':info,'Rating':rating,'Review':review,'Price':price}
df=pd.DataFrame(d)
df
# Out:
#                                           information                Rating  \
# 0   [(Renewed) boAt Rockerz 550 Bluetooth Over-Ear...  [3.8 out of 5 stars]
# 1   [(Renewed) boAt Stone 190 Portable Wireless Sp...  [4.1 out of 5 stars]
# 2   [(Renewed) Dell Latitude E5470 Intel Core i5 6...  [3.6 out of 5 stars]
# 3   [(Renewed) Jbl C50Hi Wired In Ear Earphones Wi...  [3.6 out of 5 stars]
# 4   [(Renewed) Fire-Boltt Ninja Call Pro Plus Blue...  [4.1 out of 5 stars]
# 5   [(Renewed) JBL C100SI Wired In Ear Headphone w...  [3.8 out of 5 stars]
# 6   [boAt (Renewed) Rockerz 510 Bluetooth Wireless...  [3.9 out of 5 stars]
# 7   [(Renewed) Jbl Tune 230Nc Bluetooth 5.2 Truly ...  [3.4 out of 5 stars]
# 8   [(Renewed) Honor 1.47 inches AMOLED Touch Disp...  [4.1 out of 5 stars]
# 9   [(Renewed) Infinity (JBL) Glide 120 Wireless B...  [3.8 out of 5 stars]
# 10  [(Renewed) JBL Tune 215BT in-Ear Wireless Blue...  [3.8 out of 5 stars]
# ...

# %%
info,rating,review,price=[],[],[],[]

for i in range (1,3):
    
    url=f"https://www.amazon.in/gp/bestsellers/amazon-renewed/ref=zg_bs_nav_{i}"
    page=requests.get(url)
    soup=BeautifulSoup(page.content,'html5lib')
    all_data=soup.find_all(class_="a-column a-span12 a-text-center _cDEzb_grid-column_2hIsc")
    for t in all_data:
        
        res=t.find_all(class_="a-link-normal")
        if len(res)==4:
            info.append([t.find_all(class_="a-link-normal")[1].get_text()])
            rating.append([t.find_all(class_="a-link-normal")[-2].find_all('span')[0].get_text()])
            review.append([t.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text()])
            price.append([t.find_all(class_="a-link-normal")[-1].find_all('span')[1].get_text()])
        else:
            info.append([t.find_all(class_="a-link-normal")[1].get_text()])
            rating.append([t.find_all(class_="a-link-normal")[-1].find_all('span')[0].get_text()])
            review.append([t.find_all(class_="a-link-normal")[-1].find_all('span')[1].get_text()])
            price.append('Noun')

len(info),len(rating),len(review),len(price)
# Out:
# (100, 100, 100, 100)

# %%
d={'information':info,'Rating':rating,'Review':review,'Price':price}
df=pd.DataFrame(d)
df
# Out:
#                                           information                Rating  \
# 0   [(Renewed) boAt Rockerz 550 Bluetooth Over-Ear...  [3.8 out of 5 stars]
# 1   [(Renewed) boAt Stone 190 Portable Wireless Sp...  [4.1 out of 5 stars]
# 2   [(Renewed) Dell Latitude E5470 Intel Core i5 6...  [3.6 out of 5 stars]
# 3   [(Renewed) Jbl C50Hi Wired In Ear Earphones Wi...  [3.6 out of 5 stars]
# 4   [(Renewed) Fire-Boltt Ninja Call Pro Plus Blue...  [4.1 out of 5 stars]
# ..                                                ...                   ...
# 95  [(Renewed) Mi Dual Driver in-Ear Earphones wit...  [3.7 out of 5 stars]
# 96  [(Renewed) Sony SRS-XB13 Wireless Extra Bass P...  [3.7 out of 5 stars]
# 97                     [(Renewed) Mi A2 (Gold, 64GB)]  [3.4 out of 5 stars]
# 98  [(Renewed) Dell Windows .Optiplex 3040 Tiny De...  [3.8 out of 5 stars]
# 99  [(Renewed) Dell Optiplex 380 17 inch (43.18 cm...  [2.9 out of 5 stars]
#
#      Review         Price
# 0     [989]   [₹1,189.00]
# ...

# %%
df.to_csv('Bestsellers in Amazon Renewed.csv')

# %% [markdown]
# ## Bestsellers in Apps for Android

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url="https://www.amazon.in/gp/bestsellers/mobile-apps/ref=zg_bs_nav_0"
page=requests.get(url)
soup=BeautifulSoup(page.content,'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start --><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
#
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
#
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
all_data=soup.find_all(class_="a-cardui _cDEzb_grid-cell_1uMOS expandableGrid p13n-grid-content")
len(all_data)
# Out:
# 50

# %%
apps=all_data[0]

# %%
info=apps.find_all(class_="a-link-normal")[1].get_text()
info
# Out:
# "Volume Control for Lite | Control TV Volume from Stick's Remote without IR"

# %%
cmpny_name=apps.find(class_="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y").get_text()
cmpny_name
# Out:
# 'ASFM'

# %%
rating=apps.find_all(class_="a-link-normal")[-2].find_all('span')[0].get_text()
rating
# Out:
# '3.9 out of 5 stars'

# %%
review=apps.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text()
review
# Out:
# '414'

# %%
price=apps.find_all(class_="a-link-normal")[-1].get_text()
price
# Out:
# '1 offer from ₹99.00'

# %%
info,cmpny_name,rating,review,price=[],[],[],[],[]

for t in all_data:
    
    res=t.find_all(class_="a-link-normal")
    
    if len(res)==4:
        
    
        info.append(t.find_all(class_="a-link-normal")[1].get_text())
        cmpny_name.append(t.find(class_="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y").get_text())
        rating.append(t.find_all(class_="a-link-normal")[-2].find_all('span')[0].get_text())
        review.append(t.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text())
        price.append(t.find_all(class_="a-link-normal")[-1].get_text())
        
    else:
        info.append(t.find_all(class_="a-link-normal")[1].get_text())
        cmpny_name.append(t.find(class_="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y").get_text())
        rating.append('Noun')
        review.append('Noun')
        price.append(t.find_all(class_="a-link-normal")[-1].get_text())

    
len(info),len(cmpny_name),len(rating),len(review),len(price)
# Out:
# (50, 50, 50, 50, 50)

# %%
d={'information':info,'Compny_Name':cmpny_name,'Rating':rating,'Review':review,'Price':price}

# %%
df=pd.DataFrame(d)
df
# Out:
#                                           information  \
# 0   Volume Control for Lite | Control TV Volume fr...
# 1           gFolio - Google Drive Photos & Slideshows
# 2                         Video Player for Android TV
# 3                         Beautiful Log Fireplaces HD
# 4         tinyCam PRO - Swiss knife to monitor IP cam
# 5      ScreenCast - Miracast and Google Cast Receiver
# 6                    Ocean Sunset HD - Relax Unwind..
# 7                                         AirReceiver
# 8                                         Machinarium
# 9                                   Ocean Aquarium HD
# 10                             AirPlayMirror Receiver
# 11                            Animals: Cross the line
# 12            pixFolio - Google Photos and Slideshows
# 13                      Vimu Media Player for Fire TV
# 14  Sorting Bird Game : Sort Color Birds & Relaxin...
# 15                 Brain App (Fire TV/Tablet Edition)
# ...

# %%
info,cmpny_name,rating,review,price=[],[],[],[],[]

for i in range (1,3):
    url=f"https://www.amazon.in/gp/bestsellers/mobile-apps/ref=zg_bs_nav_{i}"
    page=requests.get(url)
    soup=BeautifulSoup(page.content,'html5lib')
    all_data=soup.find_all(class_="a-cardui _cDEzb_grid-cell_1uMOS expandableGrid p13n-grid-content")
    for t in all_data:
    
        res=t.find_all(class_="a-link-normal")
    
        if len(res)==4:


            info.append(t.find_all(class_="a-link-normal")[1].get_text())
            cmpny_name.append(t.find(class_="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y").get_text())
            rating.append(t.find_all(class_="a-link-normal")[-2].find_all('span')[0].get_text())
            review.append(t.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text())
            price.append(t.find_all(class_="a-link-normal")[-1].get_text())

        else:
            info.append(t.find_all(class_="a-link-normal")[1].get_text())
            cmpny_name.append(t.find(class_="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y").get_text())
            rating.append('Noun')
            review.append('Noun')
            price.append(t.find_all(class_="a-link-normal")[-1].get_text())

    
len(info),len(cmpny_name),len(rating),len(review),len(price)
# Out:
# (100, 100, 100, 100, 100)

# %%
d={'information':info,'Compny_Name':cmpny_name,'Rating':rating,'Review':review,'Price':price}

# %%
df=pd.DataFrame(d)
df
# Out:
#                                           information  \
# 0   Volume Control for Lite | Control TV Volume fr...
# 1           gFolio - Google Drive Photos & Slideshows
# 2                         Video Player for Android TV
# 3                         Beautiful Log Fireplaces HD
# 4         tinyCam PRO - Swiss knife to monitor IP cam
# ..                                                ...
# 95                        Photo Viewer for Android TV
# 96  ADB on Boot | Run adb commands on boot automat...
# 97                         AirPlay Mirroring Receiver
# 98                                    Ahhh! Asteroids
# 99                               Pirates vs. Monsters
#
#                          Compny_Name              Rating Review  \
# 0                               ASFM  3.9 out of 5 stars    414
# 1                      Snapwood Apps  3.6 out of 5 stars    262
# 2              Prosperwave CO., LTD.  2.7 out of 5 stars     23
# ...

# %%
df.to_csv('Bestsellers in Apps for Android.csv')

# %% [markdown]
# ## Bestsellers in Baby Products

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url='https://www.amazon.in/gp/bestsellers/baby/ref=zg_bs_nav_0'
page=requests.get(url)
soup=BeautifulSoup(page.content,'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start --><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
#
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
#
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
baby_product=soup.find_all(class_="a-column a-span12 a-text-center _cDEzb_grid-column_2hIsc")
len(baby_product)
# Out:
# 50

# %%
first=baby_product[0]

# %%
info=first.find(class_="_cDEzb_p13n-sc-css-line-clamp-3_g3dy1").get_text()
info
# Out:
# 'Pampers All round Protection Pants, Medium size baby diapers (MD) 76 Count, Anti Rash diapers, Lotion with Aloe Vera'

# %%
review=first.find_all(class_="a-link-normal")[-2].find('span').get_text()
review
# Out:
# '4.3 out of 5 stars'

# %%
rating=first.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text()
rating
# Out:
# '266,790'

# %%
MRP=first.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text()
MRP
# Out:
# '₹892.00'

# %%
info,review,rating,MRP=[],[],[],[]

for t in baby_product:
    
    info.append(t.find(class_="_cDEzb_p13n-sc-css-line-clamp-3_g3dy1").get_text())
    review.append(t.find_all(class_="a-link-normal")[-2].find('span').get_text())
    rating.append(t.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text())
    MRP.append(t.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())
    
len(info),len(review),len(rating),len(MRP)
# Out:
# (50, 50, 50, 50)

# %%
d={'Information':info,'Review':review,'Rating':rating,'Price':MRP}

# %%
pf=pd.DataFrame(d)
pf
# Out:
#                                           Information              Review  \
# 0   Pampers All round Protection Pants, Medium siz...  4.3 out of 5 stars
# 1   Huggies Complete Comfort Wonder Pants Extra La...  4.2 out of 5 stars
# 2   MamyPoko Pants for Babies, Extra Absorb M87, S...  4.3 out of 5 stars
# 3   Little's Soft Cleansing Baby Wipes Lid, 80 Wip...  4.4 out of 5 stars
# 4   Little's Baby Pants Diapers with Wetness Indic...  4.0 out of 5 stars
# 5   Pampers Premium Care Pants, Extra Large size b...  4.5 out of 5 stars
# 6   Pampers Active Baby Diapers, New Born, Extra S...  4.5 out of 5 stars
# 7   Supples Baby Pants Diapers, Large (9 - 14 kg),...  4.0 out of 5 stars
# 8   Mee Mee Baby Gentle Wet Wipes with Aloe Vera e...  4.4 out of 5 stars
# 9   Little Angel Extra Dry Baby Pants Diaper, Medi...  4.0 out of 5 stars
# 10  Himalaya Total Care Baby Pants Diapers, Extra ...  4.1 out of 5 stars
# 11  LuvLap Baby Diaper Pants L Size (Large) , with...  4.0 out of 5 stars
# ...

# %%
info,review,rating,MRP=[],[],[],[]

for i in range (1,3):
    
    url=f'https://www.amazon.in/gp/bestsellers/baby/ref=zg_bs_nav_{i}'
    page=requests.get(url)
    soup=BeautifulSoup(page.content,'html5lib')
    baby_product=soup.find_all(class_="a-column a-span12 a-text-center _cDEzb_grid-column_2hIsc")
    for t in baby_product:
    
        info.append(t.find(class_="_cDEzb_p13n-sc-css-line-clamp-3_g3dy1").get_text())
        review.append(t.find_all(class_="a-link-normal")[-2].find('span').get_text())
        rating.append(t.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text())
        MRP.append(t.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())
    
len(info),len(review),len(rating),len(MRP)
# Out:
# (100, 100, 100, 100)

# %%
d={'Information':info,'Review':review,'Rating':rating,'Price':MRP}

# %%
pf=pd.DataFrame(d)
pf
# Out:
#                                           Information              Review  \
# 0   Pampers All round Protection Pants, Medium siz...  4.3 out of 5 stars
# 1   Huggies Complete Comfort Wonder Pants Extra La...  4.2 out of 5 stars
# 2   MamyPoko Pants for Babies, Extra Absorb M87, S...  4.3 out of 5 stars
# 3   Little's Soft Cleansing Baby Wipes Lid, 80 Wip...  4.4 out of 5 stars
# 4   Little's Baby Pants Diapers with Wetness Indic...  4.0 out of 5 stars
# ..                                                ...                 ...
# 95  LuvLap Baby Grooming Scissors & Nail Clipper S...  4.4 out of 5 stars
# 96  Mamaearth Moisturizing Baby Bathing Soap Bar, ...  4.2 out of 5 stars
# 97                  LuvLap Bunny Food & fruit nibbler  4.2 out of 5 stars
# 98  Dabur Lal Tail : Ayurvedic Baby Massage Oil – ...  4.4 out of 5 stars
# 99                 Himalaya Gentle Baby Soap (4N*75g)  4.4 out of 5 stars
#
#      Rating    Price
# 0   266,790  ₹892.00
# 1   213,316  ₹779.00
# ...

# %%
pf.to_csv('Bestsellers in Baby Products.csv')

# %% [markdown]
# ## Bestsellers in Bags, Wallets and Luggage

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url='https://www.amazon.in/gp/bestsellers/luggage/ref=zg_bs_nav_0'
page=requests.get(url)
soup=BeautifulSoup(page.content,'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start --><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
#
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
#
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
all_data=soup.find_all(class_="a-column a-span12 a-text-center _cDEzb_grid-column_2hIsc")
len(all_data)
# Out:
# 50

# %%
first=all_data[0]

# %%
info=first.find_all(class_="a-link-normal")[1].get_text()
info
# Out:
# 'GLUN Bolt Electronic Portable Fishing Hook Type Digital LED Screen Luggage Weighing Scale, 50 kg/110 Lb (Black)'

# %%
rating=first.find_all(class_="a-link-normal")[-2].find('span').get_text()
rating
# Out:
# '3.9 out of 5 stars'

# %%
review=first.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text()
review
# Out:
# '18,175'

# %%
price=first.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text()
price
# Out:
# '₹339.00'

# %%
info,rating,review,price=[],[],[],[]

for t in all_data:
    res=t.find_all(class_="a-link-normal")
    if len(res)==4:
    
        info.append(t.find_all(class_="a-link-normal")[1].get_text())
        rating.append(t.find_all(class_="a-link-normal")[-2].find('span').get_text())
        review.append(t.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text())
        price.append(t.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())
    else:
        info.append(t.find_all(class_="a-link-normal")[1].get_text())
        rating.append('Null')
        review.append('Null')
        price.append(t.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())

    
len(info),len(rating),len(review),len(price)
# Out:
# (50, 50, 50, 50)

# %%
d={'Information':info,'Rating':rating,'Reiew':review,'Price':price}

# %%
df=pd.DataFrame(d)
df
# Out:
#                                           Information              Rating  \
# 0   Avimee Herbal Keshpallav Hair Oil for Men and ...  4.1 out of 5 stars
# 1   Brillare 100% Natural Real Neem Face Wash for ...  4.1 out of 5 stars
# 2           Himalaya Purifying Neem Face Wash, 400 ml  4.4 out of 5 stars
# 3   Dettol Liquid Handwash Refill - Original Hand ...  4.5 out of 5 stars
# 4   L'Oréal Paris Semi-Permanent Hair Colour, Ammo...  4.3 out of 5 stars
# 5   Dettol Original Germ Protection Bathing Soap B...  4.5 out of 5 stars
# 6   Pears Pure & Gentle Moisturising Bathing Bar S...  4.5 out of 5 stars
# 7   Neutrogena Ultra sheer Sunscreen, SPF 50+, Ult...  4.2 out of 5 stars
# 8   NIVEA Soft Light Moisturizer for Face, Hand & ...  4.4 out of 5 stars
# 9   Maybelline New York Compact Powder, With SPF t...  4.1 out of 5 stars
# 10  Cetaphil Face Wash Gentle Skin Cleanser for Dr...  4.3 out of 5 stars
# 11  Garnier Skin Naturals, Face Serum, Increases S...  4.0 out of 5 stars
# ...

# %%
info,rating,review,price=[],[],[],[]

for i in range (1,3):
    
    url=f'https://www.amazon.in/gp/bestsellers/luggage/ref=zg_bs_nav_{i}'
    page=requests.get(url)
    soup=BeautifulSoup(page.content,'html5lib')
    all_data=soup.find_all(class_="a-column a-span12 a-text-center _cDEzb_grid-column_2hIsc")
    for t in all_data:
        res=t.find_all(class_="a-link-normal")
        if len(res)==4:

            info.append(t.find_all(class_="a-link-normal")[1].get_text())
            rating.append(t.find_all(class_="a-link-normal")[-2].find('span').get_text())
            review.append(t.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text())
            price.append(t.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())
        else:
            info.append(t.find_all(class_="a-link-normal")[1].get_text())
            rating.append('Null')
            review.append('Null')
            price.append(t.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())

    
len(info),len(rating),len(review),len(price)
# Out:
# (100, 100, 100, 100)

# %%
d={'Information':info,'Rating':rating,'Reiew':review,'Price':price}

# %%
df=pd.DataFrame(d)
df
# Out:
#                                           Information              Rating  \
# 0   GLUN Bolt Electronic Portable Fishing Hook Typ...  3.9 out of 5 stars
# 1   WildHorn Brown RFID Blocking Leather Wallet fo...  4.0 out of 5 stars
# 2   Urban Forest Oliver Blue RFID Blocking Leather...  4.3 out of 5 stars
# 3   Lavie Sport Lino Large Size 63 cms Wheel Duffl...  4.0 out of 5 stars
# 4   Boldfit Shoe Bag for Travel & Storage Travel O...  4.4 out of 5 stars
# ..                                                ...                 ...
# 95  Urban Forest Kyle RFID Blocking Black/Redwood ...  4.2 out of 5 stars
# 96  SAFARI 15 Ltrs Sea Blue Casual/School/College ...  4.0 out of 5 stars
# 97           OFIXO Faux Leather Unisex Wallet (Brown)  3.9 out of 5 stars
# 98  House of Quirk Packing Cubes 7 Pcs Travel Lugg...  4.1 out of 5 stars
# 99  Safari Hitech 35 Ltrs Water Resistant Backpack...  4.0 out of 5 stars
#
#      Reiew    Price
# 0   18,175  ₹339.00
# 1   32,662  ₹299.00
# ...

# %%
df.to_csv('Bestsellers in Bags, Wallets and Luggage.csv')

# %% [markdown]
# ## Bestsellers in Beauty

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url='https://www.amazon.in/gp/bestsellers/beauty/ref=zg_bs_nav_0'
page=requests.get(url)
soup=BeautifulSoup(page.content,'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start --><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
#
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
#
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
all_data=soup.find_all(class_="a-column a-span12 a-text-center _cDEzb_grid-column_2hIsc")
len(all_data)
# Out:
# 50

# %%
first=all_data[0]

# %%
info=first.find_all(class_="a-link-normal")[1].get_text()
info
# Out:
# 'Avimee Herbal Keshpallav Hair Oil for Men and Women | Reduces Hair fall & dandruff | Promotes Hair Growth | 100 ML'

# %%
rating=first.find_all(class_="a-link-normal")[-2].find('span').get_text()
rating
# Out:
# '4.1 out of 5 stars'

# %%
review=first.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text()
review
# Out:
# '623'

# %%
price=first.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text()
price
# Out:
# '₹495.00'

# %%
info,rating,review,price=[],[],[],[]


for t in all_data:
    res=t.find_all(class_="a-link-normal")
    if len(res)==4:
    
        info.append(t.find_all(class_="a-link-normal")[1].get_text())
        rating.append(t.find_all(class_="a-link-normal")[-2].find('span').get_text())
        review.append(t.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text())
        price.append(t.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())
    else:
        info.append(t.find_all(class_="a-link-normal")[1].get_text())
        rating.append('Null')
        review.append('NUll')
        price.append(t.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())

    
len(info),len(rating),len(review),len(price)
# Out:
# (50, 50, 50, 50)

# %%
d={'Information':info,'Rating':rating,'Reiew':review,'Price':price}

# %%
df=pd.DataFrame(d)
df
# Out:
#                                           Information              Rating  \
# 0   Avimee Herbal Keshpallav Hair Oil for Men and ...  4.1 out of 5 stars
# 1   Brillare 100% Natural Real Neem Face Wash for ...  4.1 out of 5 stars
# 2           Himalaya Purifying Neem Face Wash, 400 ml  4.4 out of 5 stars
# 3   Dettol Liquid Handwash Refill - Original Hand ...  4.5 out of 5 stars
# 4   L'Oréal Paris Semi-Permanent Hair Colour, Ammo...  4.3 out of 5 stars
# 5   Dettol Original Germ Protection Bathing Soap B...  4.5 out of 5 stars
# 6   Pears Pure & Gentle Moisturising Bathing Bar S...  4.5 out of 5 stars
# 7   Neutrogena Ultra sheer Sunscreen, SPF 50+, Ult...  4.2 out of 5 stars
# 8   NIVEA Soft Light Moisturizer for Face, Hand & ...  4.4 out of 5 stars
# 9   Maybelline New York Compact Powder, With SPF t...  4.1 out of 5 stars
# 10  Cetaphil Face Wash Gentle Skin Cleanser for Dr...  4.3 out of 5 stars
# 11  Garnier Skin Naturals, Face Serum, Increases S...  4.0 out of 5 stars
# ...

# %%
info,rating,review,price=[],[],[],[]

for i in range (1,3):
    
    url=f'https://www.amazon.in/gp/bestsellers/luggage/ref=zg_bs_nav_{i}'
    page=requests.get(url)
    soup=BeautifulSoup(page.content,'html5lib')
    all_data=soup.find_all(class_="a-column a-span12 a-text-center _cDEzb_grid-column_2hIsc")
    for t in all_data:
        res=t.find_all(class_="a-link-normal")
        if len(res)==4:

            info.append(t.find_all(class_="a-link-normal")[1].get_text())
            rating.append(t.find_all(class_="a-link-normal")[-2].find('span').get_text())
            review.append(t.find_all(class_="a-link-normal")[-2].find_all('span')[-1].get_text())
            price.append(t.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())
        else:
            info.append(t.find_all(class_="a-link-normal")[1].get_text())
            rating.append('Null')
            review.append('Null')
            price.append(t.find_all(class_="a-link-normal")[-1].find_all('span')[-1].get_text())

    
len(info),len(rating),len(review),len(price)
# Out:
# (100, 100, 100, 100)

# %%
d={'Information':info,'Rating':rating,'Reiew':review,'Price':price}

# %%
df=pd.DataFrame(d)
df
# Out:
#                                           Information              Rating  \
# 0   GLUN Bolt Electronic Portable Fishing Hook Typ...  3.9 out of 5 stars
# 1   WildHorn Brown RFID Blocking Leather Wallet fo...  4.0 out of 5 stars
# 2   Urban Forest Oliver Blue RFID Blocking Leather...  4.3 out of 5 stars
# 3   Lavie Sport Lino Large Size 63 cms Wheel Duffl...  4.0 out of 5 stars
# 4   Boldfit Shoe Bag for Travel & Storage Travel O...  4.4 out of 5 stars
# ..                                                ...                 ...
# 95  Urban Forest Kyle RFID Blocking Black/Redwood ...  4.2 out of 5 stars
# 96  SAFARI 15 Ltrs Sea Blue Casual/School/College ...  4.0 out of 5 stars
# 97           OFIXO Faux Leather Unisex Wallet (Brown)  3.9 out of 5 stars
# 98  House of Quirk Packing Cubes 7 Pcs Travel Lugg...  4.1 out of 5 stars
# 99  Safari Hitech 35 Ltrs Water Resistant Backpack...  4.0 out of 5 stars
#
#      Reiew    Price
# 0   18,175  ₹339.00
# 1   32,662  ₹299.00
# ...

# %%
df.to_csv('Bestsellers in Beauty.csv')
